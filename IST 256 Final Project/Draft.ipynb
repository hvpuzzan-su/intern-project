# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn import linear_model as lm
import collections
# %matplotlib inline
# Out:
# /Users/Hope/miniconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
data1 = pd.read_csv('round_regression_data.csv', index_col=["Player ID"])
df = pd.DataFrame(data1)
print(df.shape)
df.head()
# Out:
# (849, 6)
#            Round  Games  Total Rebounds  Free Throw Percentage  \
# Player ID
# 1              1     66             473                  0.752
# 2              2     48             107                  0.682
# 3              1     59             115                  0.512
# 4              2     57              56                  0.754
# 5              1    214             721                  0.782
#
#            Points Per Game  Total Rebounds Per Game
# Player ID
# 1                     10.4                      7.2
# 2                      6.1                      2.2
# 3                      3.5                      1.9
# 4                      3.9                      1.0
# 5                      7.5                      3.4

# %%
y = df['Round'].values
x1 = df['Games'].values
x2 = df['Total Rebounds'].values
x3 = df['Free Throw Percentage'].values
x4 = df['Points Per Game'].values
x5 = df['Total Rebounds Per Game'].values

# %%
y = df['Round'].values
X = df[['Games', 'Total Rebounds', 'Free Throw Percentage', 'Points Per Game', 'Total Rebounds Per Game']].values
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.194
# Model:                            OLS   Adj. R-squared:                  0.189
# Method:                 Least Squares   F-statistic:                     40.49
# Date:                Sat, 05 May 2018   Prob (F-statistic):           2.24e-37
# Time:                        23:43:40   Log-Likelihood:                -511.55
# No. Observations:                 849   AIC:                             1035.
# Df Residuals:                     843   BIC:                             1064.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.6815      0.100     16.839      0.000       1.485       1.877
# ...

# %%
y = df['Round'].values
X = df[['Games', 'Total Rebounds', 'Free Throw Percentage', 'Points Per Game', 'Total Rebounds Per Game']].values
model = lm.LinearRegression()
reg = model.fit(X,y)
reg.intercept_
# Out:
# /Users/Hope/miniconda3/lib/python3.6/site-packages/scipy/linalg/basic.py:1226: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)
# 1.6814524271656353

# %%
b0 = reg.intercept_
b1 = reg.coef_[0]
b2 = reg.coef_[1]
b3 = reg.coef_[2]
b4 = reg.coef_[3]
b5 = reg.coef_[4]

# %%
print('y = %.4f(%.1f) + %.4f(%.1f) + %.4f(%.3f) + %.4f(%.1f) + %.4f(.1%f) + %.2f' % (b1,x1,b2,x2,b3,x3,b4,x4,b5,x5,b0))
# Out:
# Enter Number of Games: 66
# Enter Total Rebounds Per Season: 473
# Enter Free Throw Percentage: .76
# Enter Points Per Game Average: 10.4
# Enter Total Rebounds Per Game Average: 7.2
# y = -0.0006(66.0) + 0.0001(473.0) + 0.2443(0.760) + -0.0263(10.4) + -0.0682(.17.200000) + 1.68
# Player wWill Likely be Drafted in Round:1

# %%
x1 = float(input('Enter Number of Games: '))
x2 = float(input('Enter Total Rebounds Per Season: '))
x3 = float(input('Enter Free Throw Percentage: '))
x4 = float(input('Enter Points Per Game Average: '))
x5 = float(input('Enter Total Rebounds Per Game Average: '))

y = (b1*x1) + (b2*x2) + (b3*x3) + (b4*x4) + (b5*x5) + b0
y = round(y)

print("")

if y==1:
    print('Player will likely be drafted in the first round.')
elif y==2:
    print('Player will most likely be drafted in the second round.')
else:
    print('Unlikely player will be drafted into the NBA.')

# %%
data2 = pd.read_csv('overall_pick_data.csv', index_col=["Player ID"])
data2
# Out:
#            Overall Pick   Games  Minutes Played  Free Throw Percentage  \
# Player ID
# 1                  19.0    66.0          1543.0                  0.752
# 2                  41.0    48.0           765.0                  0.682
# 3                  21.0    59.0           735.0                  0.512
# 4                  54.0    57.0           523.0                  0.754
# 5                  15.0   214.0          4260.0                  0.782
# 6                  15.0   107.0          1403.0                  0.680
# 7                  43.0    13.0           101.0                  0.273
# 8                  17.0   352.0          8341.0                  0.827
# 9                  18.0   251.0          4757.0                  0.782
# 10                 47.0   160.0          2323.0                  0.768
# 11                 50.0   213.0          4381.0                  0.810
# 12                 23.0   145.0          1850.0                  0.849
# ...

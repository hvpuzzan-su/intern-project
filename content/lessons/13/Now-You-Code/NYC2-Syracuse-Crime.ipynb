# %% [markdown]
# ## Now You Code 2: Syracuse Crime Data
#
# In this second now you code you will explore the plot.ly engine in detail using Syracuse, NY FBI crime data.

# %%
import plotly.plotly as py    
import plotly.graph_objs as go  
import cufflinks as cf
import pandas as pd

# %%
crime = pd.read_csv('https://raw.githubusercontent.com/mafudge/datasets/master/crime/syracuse-crime-data-1985-2012.csv')
crime.sample(10)
# Out:
#     Year  Months  Population  Violent crime total  \
# 19  2004      12      144278                 1312
# 11  1996      12      160033                 1398
# 26  2011      12      145822                 1302
# 16  2001      12      147577                 1562
# 25  2010      12      145170                 1291
# 12  1997      12      159610                 1430
# 2   1987      12      161228                 1158
# 15  2000      12      147306                 1565
# 21  2006      12      142062                 1515
# 27  2012      12      145934                 1372
#
#     Murder and nonnegligent Manslaughter  Forcible rape  Robbery  \
# 19                                    16             68      447
# 11                                    15             62      579
# 26                                    11             63      388
# 16                                    15             42      567
# 25                                    15             68      377
# 12                                    15             55      586
# 2                                     14             87      494
# 15                                    18             47      452
# 21                                    12             66      534
# 27                                    14             75      454
#
#     Aggravated assault  Property crime total  Burglary     ...       \
# 19                 781                  6609      1678     ...
# 11                 742                  9601      2821     ...
# 26                 840                  5275      1705     ...
# 16                 938                  7905      1810     ...
# 25                 831                  5708      2174     ...
# 12                 774                  9075      2388     ...
# 2                  563                 12120      4721     ...
# 15                1048                  7565      1846     ...
# 21                 903                  6677      1904     ...
# 27                 829                  5976      1896     ...
#
#     Violent Crime rate  Murder and nonnegligent manslaughter rate  \
# 19               909.4                                       11.1
# 11               873.6                                        9.4
# 26               892.9                                        7.5
# 16              1058.4                                       10.2
# 25               889.3                                       10.3
# 12               895.9                                        9.4
# 2                718.2                                        8.7
# 15              1062.4                                       12.2
# 21              1066.4                                        8.4
# 27               940.2                                        9.6
#
#     Forcible rape rate  Robbery rate  Aggravated assault rate  \
# 19                47.1         309.8                    541.3
# 11                38.7         361.8                    463.7
# 26                43.2         266.1                    576.0
# 16                28.5         384.2                    635.6
# 25                46.8         259.7                    572.4
# 12                34.5         367.1                    484.9
# 2                 54.0         306.4                    349.2
# 15                31.9         306.8                    711.4
# 21                46.5         375.9                    635.6
# 27                51.4         311.1                    568.1
#
#     Property crime rate  Burglary rate  Larceny-theft rate  \
# 19               4580.7         1163.0              2628.3
# 11               5999.4         1762.8              3711.7
# 26               3617.4         1169.2              2236.3
# 16               5356.5         1226.5              3519.5
# 25               3931.9         1497.6              2181.6
# 12               5685.7         1496.1              3731.6
# 2                7517.3         2928.2              4240.0
# 15               5135.6         1253.2              3354.2
# 21               4700.1         1340.3              2841.7
# 27               4095.0         1299.2              2534.0
#
#     Motor vehicle theft rate  Unnamed: 21
# 19                     789.4          NaN
# 11                     524.9          NaN
# 26                     211.9          NaN
# 16                     610.5          NaN
# 25                     252.8          NaN
# 12                     458.0          NaN
# 2                      349.2          NaN
# 15                     528.2          NaN
# 21                     518.1          NaN
# 27                     261.8          NaN
#
# [10 rows x 22 columns]

# %%
# Make a line plot of population over the years, using cufflinks crime.iplot()
# set the titles on x "Year, Y "Population" and cart title " Syracuse Population" 
# TODO: replace the ???? with appropriate values to render the chart
crime.iplot(kind = 'scatter', x = 'Year', y = 'Population', title='Syracuse Population',xTitle='Year---->',yTitle='Population ---->')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~hvpuzzan-su/10.embed" height="525px" width="100%"></iframe>

# %%
# Step 1:
# Now plot the same thing using plot.ly without cufflinks, again filling in the templates. Using plot.ly takes more effort but
# you have more control / flexibility over how the plots are rendered.
plot_data = [
    go.Scatter(x=crime['Year'], y=crime['Population'], mode="lines+markers", name="Syracuse Population", marker=dict(color='red')),
]

py.iplot({ 'data': plot_data,
            'layout': {
               'title': 'Syracuse Population',
               'xaxis': {
                 'title': 'Year'},
               'yaxis': {
                'title': 'Population'}
        }})
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~hvpuzzan-su/12.embed" height="525px" width="100%"></iframe>

# %%
# Step 2:
# Now create a line plot of "Robbery rate" versus "Motor vehicle theft rate" over time.
# NOTE: you will need two series in your plot_data 
crime.iplot(kind = 'line', x = 'Robbery rate', y = 'Motor vehicle theft rate', title = "Robbery vs Motor theft rate",xTitle='Year---->',yTitle='Population ---->')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~hvpuzzan-su/14.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Interactive Plots
#
# Finally write a program to ask for a crime metric like "Robbery" / "Burglary" / "Manslaughter" etc as input,
# then renders a plot of that metric over time as output !
#
# Note: check to make sure the entered crime metric is in the list of Pandas columns before you attempt to plot.
# It might be a good idea to print the column names before you plot.
# if it is not you should print "That is not a crime metric"

# %% [markdown]
# ## Step 3: Problem Analysis
#
# Inputs:
#
# user input of a crime metric
#
# Outputs:
#
# plot of that metric over time
#
# Algorithm (Steps in Program):
#
# Print items in crime list
# assign metric varibale to user input
# plot crime line plot based on selected user input

# %%
## Step 4: Write code here
for item in list(crime):
    print(item)
metric = input("Enter crime metric from the following list: ")

crime.iplot(kind = 'scatter', x = 'Year', y = metric, title=metric+" vs year",xTitle='Year',yTitle=metric)
# Out:
# Year
# Months
# Population
# Violent crime total
# Murder and nonnegligent Manslaughter
# Forcible rape
# Robbery
# Aggravated assault
# Property crime total
# Burglary
# Larceny-theft
# Motor vehicle theft
# Violent Crime rate
# Murder and nonnegligent manslaughter rate
# Forcible rape rate
# Robbery rate
# Aggravated assault rate
# Property crime rate
# Burglary rate
# Larceny-theft rate
# Motor vehicle theft rate
# Unnamed: 21
# Enter crime metric from the following list: Robbery
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~hvpuzzan-su/16.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Reminder of Evaluation Criteria
#
# 1. What the problem attempted (analysis, code, and answered questions) ?
# 2. What the problem analysis thought out? (does the program match the plan?)
# 3. Does the code execute without syntax error?
# 4. Does the code solve the intended problem?
# 5. Is the code well written? (easy to understand, modular, and self-documenting, handles errors)
